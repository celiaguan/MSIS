# %%
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# %matplotlib inline

# %%
import sklearn as sk
import sklearn.tree as tree
import sklearn.preprocessing as pp
import sklearn.metrics as sm

# %%
sd = pd.read_csv('Speed Dating Data.csv',encoding="ISO-8859-1").rename(columns=lambda x: x.strip())
sd.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#     ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 0   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 1   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 2   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 3   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 4   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
#
#    intel5_3  fun5_3  amb5_3
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# 3       NaN     NaN     NaN
# 4       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %%
sd.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
# wave          int64
# round         int64
# position      int64
# positin1    float64
# order         int64
# partner       int64
# pid         float64
# match         int64
# int_corr    float64
# samerace      int64
# age_o       float64
# race_o      float64
# pf_o_att    float64
# pf_o_sin    float64
# pf_o_int    float64
# pf_o_fun    float64
# pf_o_amb    float64
# pf_o_sha    float64
# dec_o         int64
# attr_o      float64
# sinc_o      float64
# intel_o     float64
# fun_o       float64
# amb_o       float64
# shar_o      float64
#              ...
# amb1_3      float64
# shar1_3     float64
# attr7_3     float64
# sinc7_3     float64
# intel7_3    float64
# fun7_3      float64
# amb7_3      float64
# shar7_3     float64
# attr4_3     float64
# sinc4_3     float64
# intel4_3    float64
# fun4_3      float64
# amb4_3      float64
# shar4_3     float64
# attr2_3     float64
# sinc2_3     float64
# intel2_3    float64
# fun2_3      float64
# amb2_3      float64
# shar2_3     float64
# attr3_3     float64
# sinc3_3     float64
# intel3_3    float64
# fun3_3      float64
# amb3_3      float64
# attr5_3     float64
# sinc5_3     float64
# intel5_3    float64
# fun5_3      float64
# amb5_3      float64
# Length: 195, dtype: object

# %%
male = sd[sd['gender']==1]
male.head()
# Out:
#      iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 100   11  1.0       1    2       1     1     10         7       NaN      4
# 101   11  1.0       1    2       1     1     10         3       NaN     10
# 102   11  1.0       1    2       1     1     10         9       NaN      6
# 103   11  1.0       1    2       1     1     10         6       NaN      3
# 104   11  1.0       1    2       1     1     10         4       NaN      1
#
#       ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 100   ...        7.0      8.0       7.0     7.0     5.0      NaN      NaN
# 101   ...        7.0      8.0       7.0     7.0     5.0      NaN      NaN
# 102   ...        7.0      8.0       7.0     7.0     5.0      NaN      NaN
# 103   ...        7.0      8.0       7.0     7.0     5.0      NaN      NaN
# 104   ...        7.0      8.0       7.0     7.0     5.0      NaN      NaN
#
#      intel5_3  fun5_3  amb5_3
# 100       NaN     NaN     NaN
# 101       NaN     NaN     NaN
# 102       NaN     NaN     NaN
# 103       NaN     NaN     NaN
# 104       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %%
female = sd[sd['gender']==0]
female.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#     ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 0   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 1   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 2   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 3   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 4   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
#
#    intel5_3  fun5_3  amb5_3
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# 3       NaN     NaN     NaN
# 4       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %% [markdown]
# x = sd[sd['wave'].between(10,22)].loc[(:,'attr1_1':'shar2_1')&(:,'gender')]
# y = sd[['gender']]
# y.isnull().sum()

# %%
features =['iid','gender','match','attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',\
           'attr2_1', 'sinc2_1','intel2_1', 'fun2_1', 'amb2_1', 'shar2_1', 'attr4_1',\
           'sinc4_1','fun4_1', 'intel4_1', 'amb4_1','shar4_1']

# %%
wave10 = sd[sd['wave'].between(10,22)].loc[:, features]
wave10.describe()
wave10.head()
# Out:
#                iid      gender        match      attr1_1      sinc1_1  \
# count  4970.000000  4970.00000  4970.000000  4932.000000  4932.000000
# mean    394.206036     0.50000     0.158954    23.959702    17.477488
# std      95.292699     0.50005     0.365670    13.385124     7.834010
# min     234.000000     0.00000     0.000000     0.000000     0.000000
# 25%     308.000000     0.00000     0.000000    15.000000    12.000000
# 50%     386.000000     0.50000     0.000000    20.000000    20.000000
# 75%     483.000000     1.00000     0.000000    30.000000    20.000000
# max     552.000000     1.00000     1.000000    95.000000    60.000000
#
#           intel1_1       fun1_1       amb1_1      shar1_1      attr2_1  \
# count  4932.000000  4932.000000  4932.000000  4910.000000  4932.000000
# mean     20.111052    17.318562     9.724114    11.431802    33.021492
# std       7.284072     6.626999     5.688571     6.612484    17.053744
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      16.000000    14.000000     5.000000     5.000000    20.000000
# 50%      20.000000    18.000000    10.000000    10.000000    30.000000
# 75%      25.000000    20.000000    15.000000    15.000000    40.000000
# max      50.000000    50.000000    30.000000    30.000000   100.000000
#
#           ...          intel2_1       fun2_1       amb2_1      shar2_1  \
# count     ...       4932.000000  4932.000000  4932.000000  4932.000000
# mean      ...         13.797648    18.293593    11.362733    11.204785
# std       ...          6.922435     7.479125     7.492686     6.598445
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...         10.000000    15.000000     5.000000     5.000000
# 50%       ...         12.000000    20.000000    10.000000    10.000000
# 75%       ...         20.000000    20.000000    15.000000    15.000000
# max       ...         40.000000    50.000000    50.000000    30.000000
#
#            attr4_1      sinc4_1       fun4_1     intel4_1       amb4_1  \
# count  4932.000000  4932.000000  4932.000000  4932.000000  4932.000000
# mean     31.999797    12.347121    17.931062    14.455799    10.842660
# std      14.767137     7.114781     6.837787     6.675540     7.621974
# min       5.000000     0.000000     0.000000     0.000000     0.000000
# 25%      20.000000    10.000000    15.000000    10.000000     5.000000
# 50%      30.000000    10.000000    20.000000    15.000000    10.000000
# 75%      40.000000    17.000000    20.000000    20.000000    15.000000
# max      95.000000    35.000000    45.000000    35.000000    50.000000
#
#            shar4_1
# count  4910.000000
# mean     12.323829
# std       6.331559
# min       0.000000
# 25%      10.000000
# 50%      10.000000
# 75%      15.000000
# max      40.000000
#
# [8 rows x 21 columns]
#       iid  gender  match  attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1  \
# 3408  234       0      0     20.0     20.0      20.0    10.0    10.0     20.0
# 3409  234       0      0     20.0     20.0      20.0    10.0    10.0     20.0
# 3410  234       0      0     20.0     20.0      20.0    10.0    10.0     20.0
# 3411  234       0      0     20.0     20.0      20.0    10.0    10.0     20.0
# 3412  234       0      0     20.0     20.0      20.0    10.0    10.0     20.0
#
#       attr2_1   ...     intel2_1  fun2_1  amb2_1  shar2_1  attr4_1  sinc4_1  \
# 3408     75.0   ...          1.0     3.0    10.0     10.0     10.0     20.0
# 3409     75.0   ...          1.0     3.0    10.0     10.0     10.0     20.0
# 3410     75.0   ...          1.0     3.0    10.0     10.0     10.0     20.0
# 3411     75.0   ...          1.0     3.0    10.0     10.0     10.0     20.0
# 3412     75.0   ...          1.0     3.0    10.0     10.0     10.0     20.0
#
#       fun4_1  intel4_1  amb4_1  shar4_1
# 3408    20.0      20.0    15.0     15.0
# 3409    20.0      20.0    15.0     15.0
# 3410    20.0      20.0    15.0     15.0
# 3411    20.0      20.0    15.0     15.0
# 3412    20.0      20.0    15.0     15.0
#
# [5 rows x 21 columns]

# %%
wave10=wave10.dropna(axis=0,how='any')
wave10.isnull().sum()
# Out:
# iid         0
# gender      0
# match       0
# attr1_1     0
# sinc1_1     0
# intel1_1    0
# fun1_1      0
# amb1_1      0
# shar1_1     0
# attr2_1     0
# sinc2_1     0
# intel2_1    0
# fun2_1      0
# amb2_1      0
# shar2_1     0
# attr4_1     0
# sinc4_1     0
# fun4_1      0
# intel4_1    0
# amb4_1      0
# shar4_1     0
# dtype: int64

# %%
df_X, y = wave10.drop(['match'], axis=1), wave10['match']

# %%
try1 = sd[['attr1_1', 'sinc1_1','intel1_1', 'fun1_1', 'amb1_1']].copy()
try1
# Out:
#       attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1
# 0        15.0     20.0      20.0    15.0    15.0
# 1        15.0     20.0      20.0    15.0    15.0
# 2        15.0     20.0      20.0    15.0    15.0
# 3        15.0     20.0      20.0    15.0    15.0
# 4        15.0     20.0      20.0    15.0    15.0
# 5        15.0     20.0      20.0    15.0    15.0
# 6        15.0     20.0      20.0    15.0    15.0
# 7        15.0     20.0      20.0    15.0    15.0
# 8        15.0     20.0      20.0    15.0    15.0
# 9        15.0     20.0      20.0    15.0    15.0
# 10       45.0      5.0      25.0    20.0     0.0
# 11       45.0      5.0      25.0    20.0     0.0
# 12       45.0      5.0      25.0    20.0     0.0
# 13       45.0      5.0      25.0    20.0     0.0
# 14       45.0      5.0      25.0    20.0     0.0
# 15       45.0      5.0      25.0    20.0     0.0
# 16       45.0      5.0      25.0    20.0     0.0
# 17       45.0      5.0      25.0    20.0     0.0
# 18       45.0      5.0      25.0    20.0     0.0
# 19       45.0      5.0      25.0    20.0     0.0
# 20       35.0     10.0      35.0    10.0    10.0
# 21       35.0     10.0      35.0    10.0    10.0
# 22       35.0     10.0      35.0    10.0    10.0
# 23       35.0     10.0      35.0    10.0    10.0
# 24       35.0     10.0      35.0    10.0    10.0
# 25       35.0     10.0      35.0    10.0    10.0
# 26       35.0     10.0      35.0    10.0    10.0
# 27       35.0     10.0      35.0    10.0    10.0
# 28       35.0     10.0      35.0    10.0    10.0
# 29       35.0     10.0      35.0    10.0    10.0
# ...       ...      ...       ...     ...     ...
# 8348     40.0     20.0      20.0    20.0     0.0
# 8349     40.0     20.0      20.0    20.0     0.0
# 8350     40.0     20.0      20.0    20.0     0.0
# 8351     40.0     20.0      20.0    20.0     0.0
# 8352     40.0     20.0      20.0    20.0     0.0
# 8353     40.0     20.0      20.0    20.0     0.0
# 8354     40.0     20.0      20.0    20.0     0.0
# 8355     40.0     20.0      20.0    20.0     0.0
# 8356     70.0      0.0      15.0    15.0     0.0
# 8357     70.0      0.0      15.0    15.0     0.0
# 8358     70.0      0.0      15.0    15.0     0.0
# 8359     70.0      0.0      15.0    15.0     0.0
# 8360     70.0      0.0      15.0    15.0     0.0
# 8361     70.0      0.0      15.0    15.0     0.0
# 8362     70.0      0.0      15.0    15.0     0.0
# 8363     70.0      0.0      15.0    15.0     0.0
# 8364     70.0      0.0      15.0    15.0     0.0
# 8365     70.0      0.0      15.0    15.0     0.0
# 8366     70.0      0.0      15.0    15.0     0.0
# 8367     70.0      0.0      15.0    15.0     0.0
# 8368     70.0      0.0      15.0    15.0     0.0
# 8369     70.0      0.0      15.0    15.0     0.0
# 8370     70.0      0.0      15.0    15.0     0.0
# 8371     70.0      0.0      15.0    15.0     0.0
# 8372     70.0      0.0      15.0    15.0     0.0
# 8373     70.0      0.0      15.0    15.0     0.0
# 8374     70.0      0.0      15.0    15.0     0.0
# 8375     70.0      0.0      15.0    15.0     0.0
# 8376     70.0      0.0      15.0    15.0     0.0
# 8377     70.0      0.0      15.0    15.0     0.0
#
# [8378 rows x 5 columns]

# %%
sd[['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1']].iloc[0,:].sum()
# Out:
# 85.0

# %%
len(sd[['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1']].columns)
# Out:
# 5

# %%
sd[['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1']].iloc[0,0]
# Out:
# 15.0

# %%
def scale10(question):
    for i in range(0, len(question)):
        total = question.iloc[i,:].sum()/100
        for j in range(0, len(question.columns)):
            question.iloc[i,j]=(question.iloc[i,j]/total)/10
    return question

# %% [markdown]
# notion of control of the other group (a/b testing)
# top 3: clustering
# start small
# qausi

# %%
try1.iloc[0,0]
# Out:
# 15.0

# %%
import warnings
warnings.filterwarinigs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4a59d801072b> in <module>()
# ----> 1 warnings.simplefilter(action = "ignore", category = FutureWarning)
#       2 from subprocess import check_output
#
# NameError: name 'warnings' is not defined

# %%
pd.to_numeric(sd['income'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "69,487.00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-81525499ae94> in <module>()
# ----> 1 pd.to_numeric(sd['income'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "69,487.00" at position 0

# %%
features =['gender','match','round','order','samerace','age','field_cd','race','imprace',\
          'imprelig','date','go_out','sports',\
          'tvsports','exercise','dining','museums','art','hiking','gaming','clubbing',\
          'reading','tv','theater','movies','music','shopping','yoga',\
          'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',\
           'attr2_1', 'sinc2_1','intel2_1', 'fun2_1', 'amb2_1', 'shar2_1', 'attr3_1',\
           'sinc3_1','fun3_1', 'intel3_1', 'amb3_1']

# %%
sd[features].corr()
# Out:
#             gender     match     round     order  samerace       age  \
# gender    1.000000 -0.000530  0.020630  0.006685 -0.000966  0.070574
# match    -0.000530  1.000000 -0.033257 -0.038731  0.013028 -0.035055
# round     0.020630 -0.033257  1.000000  0.399942  0.034067  0.007013
# order     0.006685 -0.038731  0.399942  1.000000  0.008640  0.002959
# samerace -0.000966  0.013028  0.034067  0.008640  1.000000  0.007140
# age       0.070574 -0.035055  0.007013  0.002959  0.007140  1.000000
# field_cd -0.080728 -0.024641  0.073147  0.029480 -0.024828  0.138069
# race     -0.018857 -0.013268 -0.075542 -0.030199 -0.269159 -0.058010
# imprace  -0.113211 -0.049032  0.067014  0.026731  0.090517 -0.147194
# imprelig -0.199148 -0.026014  0.061455  0.025282  0.071044 -0.054876
# date     -0.101009 -0.063610  0.062259  0.024609 -0.040874  0.006817
# go_out    0.016818 -0.060526  0.061616  0.024422 -0.075643  0.084113
# sports    0.232275  0.021666  0.030284  0.011529  0.028588 -0.079708
# tvsports  0.146566 -0.004472  0.024250  0.009880 -0.038529 -0.129793
# exercise -0.084296  0.009470 -0.069244 -0.027810  0.038704 -0.031302
# dining   -0.205830  0.033912 -0.016235 -0.005805 -0.046896  0.035101
# museums  -0.214402  0.014954  0.017329  0.007602  0.001680  0.113233
# art      -0.221855  0.031545  0.032545  0.013617  0.023894  0.089868
# hiking   -0.079289  0.024143 -0.007266 -0.003163  0.015345  0.048261
# gaming    0.219619  0.013543  0.073035  0.028434 -0.056567 -0.174113
# clubbing -0.061141  0.055435 -0.006282 -0.002380 -0.073410 -0.095330
# reading  -0.113280  0.020222  0.031754  0.013588  0.004395  0.108467
# tv       -0.171096 -0.014542 -0.025750 -0.010099 -0.023792 -0.180684
# theater  -0.313942  0.000087 -0.007354 -0.001886 -0.018154  0.014627
# movies   -0.162740 -0.022989  0.005433  0.001885 -0.026814 -0.014522
# music    -0.076850  0.023093 -0.034991 -0.014046 -0.043633 -0.053928
# shopping -0.330718 -0.001333 -0.007623 -0.002478 -0.055101 -0.150975
# sinc1_1  -0.135430 -0.111654 -0.204228
# intel1_1 -0.206869  0.094611 -0.083255
# fun1_1    0.218767 -0.069048 -0.068479
# amb1_1    0.098096 -0.000744  0.322536
# shar1_1  -0.108311  0.048629 -0.062502
# attr2_1   0.034507 -0.102477 -0.013442
# sinc2_1  -0.009038  0.004946 -0.014293
# intel2_1  0.036862  0.094189  0.046991
# fun2_1   -0.107831 -0.055863 -0.089294
# amb2_1    0.042016  0.132355  0.094031
# shar2_1  -0.048449  0.054813 -0.010755
# attr3_1   0.437902  0.368838  0.301308
# sinc3_1   0.190424  0.227719  0.166814
# fun3_1    1.000000  0.259608  0.348876
# intel3_1  0.259608  1.000000  0.331122
# amb3_1    0.348876  0.331122  1.000000
#
# [45 rows x 45 columns]

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(sd[features].corr(),linewidths=.5, ax=ax)

# %%
# attr_o
# 'intel_o'
# 'shar_o'
# 'round'
#'like_o' & 'attr_o'
#  'imprelig'&'imprace' 
# 'go_out'& 'date'
# 'art', 'theater', 'shopping', 'sports','movies', 'shar2_1', 'dining', 'amb3_1'
# attr1_1/attr2_1 is highly corr with several other attribution
# convert income to numeric!!!!!!
keep =['gender','match','order','age','field_cd','race','imprace',\
       'date','exercise','museums','hiking','gaming','clubbing',\
        'reading','tv','music','yoga', 'sinc1_1', 'intel1_1',\
       'fun1_1', 'amb1_1', 'shar1_1', 'sinc2_1','intel2_1', 'fun2_1', \
       'amb2_1','sinc3_1','fun3_1', 'intel3_1']

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(sd[keep].corr(),linewidths=.5, ax=ax)

# %%
temp1 = sd[keep].apply(lambda x: x.fillna(x.median()), axis=1)

# %%
temp1.isnull().sum()
# Out:
# gender      0
# match       0
# order       0
# age         0
# field_cd    0
# race        0
# imprace     0
# date        0
# sinc1_1     0
# intel1_1    0
# fun1_1      0
# amb1_1      0
# shar1_1     0
# sinc2_1     0
# intel2_1    0
# fun3_1      0
# intel3_1    0
# dtype: int64

# %%
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.cluster import Birch
from sklearn.cluster import AgglomerativeClustering

bestSil = -1
for k in range(2,10):
    clus = [KMeans(n_clusters=k,n_jobs=-1), Birch(n_clusters=k), 
            AgglomerativeClustering(n_clusters=k)]
    for cl in clus:
        res = cl.fit(temp1)
        sil = metrics.silhouette_score(temp1, res.labels_)
        print (str(cl)[:10] + ' with k =' +str(k) + ": " + str(round(sil,4)))
        if (sil > bestSil):
            bestSil = sil
            bestCl = cl
# Out:
# KMeans(alg with k =2: 0.1499
# Birch(bran with k =2: 0.1992
# Agglomerat with k =2: 0.1699
# KMeans(alg with k =3: 0.1403
# Birch(bran with k =3: 0.1963
# Agglomerat with k =3: 0.1605
# KMeans(alg with k =4: 0.1169
# Birch(bran with k =4: 0.1328
# Agglomerat with k =4: 0.1203
# KMeans(alg with k =5: 0.1299
# Birch(bran with k =5: 0.0612
# Agglomerat with k =5: 0.0784
# KMeans(alg with k =6: 0.1259
# Birch(bran with k =6: 0.0728
# Agglomerat with k =6: 0.0882
# KMeans(alg with k =7: 0.0862
